# %%
# %matplotlib inline

import pickle
import cv2
from apc_data import APCSample
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # one sample

# %%
sib_sample_path = '/home/leus/ros/indigo' + \
 '/src/start-jsk/jsk_apc/jsk_apc2016_common/debug/data/astra_data/barkely_hide_bones_20160619154533_bin_f'

# %%
with open(sib_sample_path + '.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data.keys()
# Out:
# ['dist2shelf_image',
#  'depth_image',
#  'objects',
#  'height3D_image',
#  'target_object']

# %%
plt.imshow(data['dist2shelf_image'])

# %%
plt.imshow(data['depth_image'])
data['depth_image'][100:120, 300:400]
# Out:
# array([[ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        ...,
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan],
#        [ nan,  nan,  nan, ...,  nan,  nan,  nan]], dtype=float16)

# %%
def visualize_color_image(img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_HSV2RGB))

    
def basic_image_check(img):
    print np.max(img)
    print img.dtype
    

apc_sample = APCSample(labeled=True, data_2016_prefix=sib_sample_path)

# %% [markdown]
# # using tools

# %%
import utils

# %%
utils.visualize_apc_sample_feature(apc_sample)
# Out:
# max of img depth  nan
# dtype of img depth  float16
# max of img mask_image  True
# dtype of img mask_image  bool
# max of img dist2shelf_image  44
# dtype of img dist2shelf_image  uint8
# max of img height3D_image  255
# dtype of img height3D_image  uint8

# %%
utils.visualize_apc_sample_data_dict(apc_sample)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-105d335bf0dd> in <module>()
# ----> 1 utils.visualize_apc_sample_data_dict(apc_sample)
#
# /home/leus/ros/indigo/src/start-jsk/jsk_apc/jsk_apc2016_common/python/jsk_apc2016_common/rbo_segmentation/utils.pyc in visualize_apc_sample_data_dict(apc_sample)
#      24
#      25 def visualize_apc_sample_data_dict(apc_sample):
# ---> 26     basic_image_check(apc_sample.data_dict['depth'], 'depth')
#      27     basic_image_check(apc_sample.data_dict['mask_image'], 'mask_image')
#      28     basic_image_check(
#
# KeyError: 'depth'

# %% [markdown]
# # Dataset

# %%
dataset_path = '/home/leus/ros/indigo/src/start-jsk/jsk_apc/jsk_apc2016_common/data/dataset.pkl'

with open(dataset_path, 'rb') as f:
    dataset = pickle.load(f)

# %%
dataset.samples
# Out:
# [<jsk_apc2016_common.rbo_segmentation.apc_data.APCSample at 0x7f0715c22d10>,
#  <jsk_apc2016_common.rbo_segmentation.apc_data.APCSample at 0x7f07159a0a10>,
#  <jsk_apc2016_common.rbo_segmentation.apc_data.APCSample at 0x7f07159a0f90>,
#  <jsk_apc2016_common.rbo_segmentation.apc_data.APCSample at 0x7f07159a9590>,
#  <jsk_apc2016_common.rbo_segmentation.apc_data.APCSample at 0x7f07159a9bd0>,
#  <jsk_apc2016_common.rbo_segmentation.apc_data.APCSample at 0x7f07159b6250>,
#  <jsk_apc2016_common.rbo_segmentation.apc_data.APCSample at 0x7f07159b6890>,
#  <jsk_apc2016_common.rbo_segmentation.apc_data.APCSample at 0x7f07159b6ed0>,
#  <jsk_apc2016_common.rbo_segmentation.apc_data.APCSample at 0x7f07159c1550>,
#  <jsk_apc2016_common.rbo_segmentation.apc_data.APCSample at 0x7f07159c1b90>,
#  <jsk_apc2016_common.rbo_segmentation.apc_data.APCSample at 0x7f07159cd190>,
#  <jsk_apc2016_common.rbo_segmentation.apc_data.APCSample at 0x7f07159cd7d0>]

# %%
first_sample = dataset.samples[0]
utils.visualize_apc_sample_feature(first_sample)
# Out:
# max of img depth  nan
# dtype of img depth  float16
# max of img mask_image  True
# dtype of img mask_image  bool
# max of img dist2shelf_image  53
# dtype of img dist2shelf_image  uint8
# max of img height3D_image  255
# dtype of img height3D_image  uint8

# %% [markdown]
# # Predictor

# %%
dataset_path = '/home/leus/ros/indigo/src/start-jsk/jsk_apc/jsk_apc2016_common/data/trained_segmenter_2016.pkl'

with open(dataset_path, 'rb') as f:
    bp = pickle.load(f)

# %%
bp.fit(dataset)
# Out:
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# stop
# /home/leus/ros/indigo/src/start-jsk/jsk_apc/jsk_apc2016_common/python/jsk_apc2016_common/rbo_segmentation/probabilistic_segmentation.py:466: RuntimeWarning: invalid value encountered in divide
#   likelihood = histogram / np.sum(histogram)

# %%
sample = dataset.samples[0]

# %%
sample.object_masks
# Out:
# {}
